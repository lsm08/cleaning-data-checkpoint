# %% [markdown]
# # Checkpoint Three: Cleaning Data
#
# Now you are ready to clean your data. Before starting coding, provide the link to your dataset below.
#
# My dataset:        https://www.kaggle.com/datasets/arnabchaki/data-science-salaries-2023
#
# Import the necessary libraries and create your dataframe(s).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('./ds_salaries.csv')
df.head()
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# 1   30000             USD          30000                 US           100
# 2   25500             USD          25500                 US           100
# 3  175000             USD         175000                 CA           100
# 4  120000             USD         120000                 CA           100
#
#   company_location company_size
# 0               ES            L
# ...

# %% [markdown]
# ## Missing Data
#
# Test your dataset for missing data and handle it as needed. Make notes in the form of code comments as to your thought process.

# %%
# checking the missing data

#check for null records
print(df.isnull().sum())
print(df.describe())
print("Null Salary count: ", df.salary.isnull().sum())
print("Count of remote_ratio", df.remote_ratio.value_counts())
df.experience_level.value_counts()
df.employment_type.value_counts()
df[['employment_type','salary_in_usd']].groupby('employment_type').mean().round(2)
# df['salary_in_usd'] = df['salary_in_usd'].round(2)
df["job_title"].value_counts()[:6] # choosing the best job_titles
df['salary_in_usd'].describe([.20,.45,.99])
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64
#          work_year        salary  salary_in_usd  remote_ratio
# count  3755.000000  3.755000e+03    3755.000000   3755.000000
# mean   2022.373635  1.906956e+05  137570.389880     46.271638
# std       0.691448  6.716765e+05   63055.625278     48.589050
# min    2020.000000  6.000000e+03    5132.000000      0.000000
# 25%    2022.000000  1.000000e+05   95000.000000      0.000000
# 50%    2022.000000  1.380000e+05  135000.000000      0.000000
# 75%    2023.000000  1.800000e+05  175000.000000    100.000000
# max    2023.000000  3.040000e+07  450000.000000    100.000000
# Null Salary count:  0
# Count of remote_ratio remote_ratio
# 0      1923
# 100    1643
# 50      189
# ...

# %% [markdown]
# ## Irregular Data
#
# Detect outliers in your dataset and handle them as needed. Use code comments to make notes about your thought process.

# %%
# Create a sample dataset

data = df

# Create a box plot to detect outliers
sns.boxplot(data)
plt.title("Box Plot with Outliers")
plt.xlabel("Data")
plt.show()

# %% [markdown]
# ## Unnecessary Data
#
# Look for the different types of unnecessary data in your dataset and address it as needed. Make sure to use code comments to illustrate your thought process.

# %%
# This is un necessary data as they  r duplicates
# Finding duplicate rows
duplicate_rows = df[df.duplicated(keep='first')]
num_duplicates = duplicate_rows.shape[0]
# Displaying the duplicate rows
print(f"Number of duplicate rows: {num_duplicates}")
print(duplicate_rows)

# Create a sample dataset
data1 = duplicate_rows

# Create a box plot to detect outliers
sns.boxplot(data1)
plt.title("Box Plot with Outliers")
plt.xlabel("Data")
plt.show()
# Out:
# Number of duplicate rows: 1171
#       work_year experience_level employment_type           job_title  salary  \
# 115        2023               SE              FT      Data Scientist  150000
# 123        2023               SE              FT  Analytics Engineer  289800
# 153        2023               MI              FT       Data Engineer  100000
# 154        2023               MI              FT       Data Engineer   70000
# 160        2023               SE              FT       Data Engineer  115000
# ...         ...              ...             ...                 ...     ...
# 3439       2022               MI              FT      Data Scientist   78000
# 3440       2022               SE              FT       Data Engineer  135000
# 3441       2022               SE              FT       Data Engineer  115000
# 3586       2021               MI              FT       Data Engineer  200000
# 3709       2021               MI              FT      Data Scientist   76760
#
# ...

# %% [markdown]
# ## Inconsistent Data
#
# Check for inconsistent data and address any that arises. As always, use code comments to illustrate your thought process.

# %%
# Incosistent data - if the same data exists in different formats in multiple tables. 
# The data set has only one table, no inconsistent data

# %% [markdown]
# ## Summarize Your Results
#
# Make note of your answers to the following questions.
#
# 1. **Did you find all four types of dirty data in your dataset?**
#
# - <span style="color: var(--vscode-foreground);">The data set was really clean&nbsp;</span>
#
# - Duplicates - 1171 duplicate rows were found
#
# - No inconsistent data - single table
#
# - Missing data - No missing data
#
# - Inaccurate data - Some of the job titles are similar. I don't have enough info to confirm and replace
#
# -
#
#
# **
#
# 1. **Did the process of cleaning your data give you new insights into your dataset?**
#
# **
#
# - <span style="color: var(--vscode-foreground);">Removing the duplicates may have helped. Box plot showed fewer dots. Bar chart or scatter graph may have shown the difference better.</span>
# - <span style="color: var(--vscode-foreground);"><br></span>
#
# **
#
# 1. **Is there anything you would like to make note of when it comes to manipulating the data and making visualizations?**
#
# **
#
# - I could have performed the previous assignments visualizations using the de-duplicated data.  Mean, deviatiojn, count based metrics and plots would be different.
